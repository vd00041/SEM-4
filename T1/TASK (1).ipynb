# %% [markdown]
# # Q1. Find the total units produced by each product_category.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('production_analysis_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   production_id           50 non-null     int64
#  1   product_category        50 non-null     object
#  2   factory                 50 non-null     object
#  3   shift                   50 non-null     object
#  4   supervisor              50 non-null     object
#  5   units_produced          50 non-null     int64
#  6   defective_units         50 non-null     int64
#  7   production_time_hr      50 non-null     float64
#  8   machine_downtime_hr     50 non-null     float64
#  9   energy_consumption_kwh  50 non-null     int64
#  10  profit                  50 non-null     int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 4.4+ KB

# %%
df.head()
# Out:
#    production_id product_category  factory    shift supervisor  \
# 0            101       Automotive  Plant_A    Night         S1
# 1            102       Automotive  Plant_A    Night         S2
# 2            103      Electronics  Plant_A    Night         S4
# 3            104      Electronics  Plant_B  Morning         S3
# 4            105        Furniture  Plant_A    Night         S3
#
#    units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0             627               12                6.58                 0.56
# 1             602               32                6.60                 0.32
# 2             666               39                7.76                 0.78
# 3             474               22                6.97                 1.44
# 4             476               21                8.92                 1.15
#
#    energy_consumption_kwh  profit
# 0                    1028   12286
# 1                    1038   18279
# 2                    1084   23261
# 3                    1144   11674
# 4                    1349   12045

# %%
df.groupby("product_category").sum("units_produced")
# Out:
#                   production_id  units_produced  defective_units  \
# product_category
# Automotive                 2260            9408              385
# Electronics                1973            7491              362
# Furniture                  2042            7251              328
#
#                   production_time_hr  machine_downtime_hr  \
# product_category
# Automotive                    135.94                17.00
# Electronics                   130.53                14.29
# Furniture                     122.96                14.64
#
#                   energy_consumption_kwh  profit
# product_category
# Automotive                         21581  330745
# Electronics                        18145  271132
# Furniture                          18663  286961

# %% [markdown]
# # Q2. Calculate the average profit for each factory.

# %%
df.groupby("factory").mean("profit")["profit"]
# Out:
# factory
# Plant_A    18044.375000
# Plant_B    16973.384615
# Plant_C    18086.076923
# Name: profit, dtype: float64

# %% [markdown]
# # Q3. Find the total defective_units for each shift.

# %%
df.groupby("shift").sum()["defective_units"]
# Out:
# shift
# Evening    132
# Morning    472
# Night      471
# Name: defective_units, dtype: int64

# %% [markdown]
# # Q4. Calculate the average production_time_hr for each supervisor.

# %%
df.groupby("supervisor").mean(numeric_only=True)["production_time_hr"]
# Out:
# supervisor
# S1    7.801818
# S2    7.450000
# S3    7.882000
# S4    7.956154
# Name: production_time_hr, dtype: float64

# %% [markdown]
# # Q5. Find the total energy_consumption_kwh for each factory and shift.

# %%
df.groupby(["factory","shift"]).sum(numeric_only=True)["energy_consumption_kwh"]
# Out:
# factory  shift
# Plant_A  Evening     3330
#          Morning    11144
#          Night      12913
# Plant_B  Evening     2889
#          Morning     7923
#          Night       4981
# Plant_C  Evening     2214
#          Morning     5632
#          Night       7363
# Name: energy_consumption_kwh, dtype: int64

# %% [markdown]
# # Q6. For each product_category, calculate:
# total units_produced
# average profit
# maximum defective_units.

# %%
df.groupby("product_category").agg({'units_produced':'sum',
                                   'profit':'mean',
                                   'defective_units':'max'})
# Out:
#                   units_produced        profit  defective_units
# product_category
# Automotive                  9408  18374.722222               34
# Electronics                 7491  16945.750000               40
# Furniture                   7251  17935.062500               39

# %% [markdown]
# # Q7. For each factory, calculate:
# mean production_time_hr
# median machine_downtime_hr.

# %%
df.groupby("factory").agg({'production_time_hr':'mean',
                                        'machine_downtime_hr':'median'})
# Out:
#          production_time_hr  machine_downtime_hr
# factory
# Plant_A            7.890000                0.945
# Plant_B            7.579231                1.070
# Plant_C            7.810769                0.850

# %% [markdown]
# # Q8. For each shift, compute:
# minimum profit
# maximum profit
# average units_produced.

# %%
df.groupby('shift').agg({'profit':'max',
                        'profit':'min',
                        'units_produced':'mean'})
# Out:
#          profit  units_produced
# shift
# Evening   10009      524.857143
# Morning   10722      482.090909
# Night     12045      470.000000

# %% [markdown]
# # Q9. For each supervisor, calculate:
# total units_produced
# total defective_units.

# %%
df.groupby('supervisor').agg({
    'units_produced':'sum',
    'defective_units':'sum'
})
# Out:
#             units_produced  defective_units
# supervisor
# S1                    5231              209
# S2                    6069              264
# S3                    7418              273
# S4                    5432              329

# %% [markdown]
# # Q10. Using apply(), calculate the defect rate for each row:
# defect_rate=defective_units/units_produced

# %%
df['defect_rate']=df.apply(lambda x:x['defective_units']/x['units_produced'],axis=1)
df.head()
# Out:
#    production_id product_category  factory    shift supervisor  \
# 0            101       Automotive  Plant_A    Night         S1
# 1            102       Automotive  Plant_A    Night         S2
# 2            103      Electronics  Plant_A    Night         S4
# 3            104      Electronics  Plant_B  Morning         S3
# 4            105        Furniture  Plant_A    Night         S3
#
#    units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0             627               12                6.58                 0.56
# 1             602               32                6.60                 0.32
# 2             666               39                7.76                 0.78
# 3             474               22                6.97                 1.44
# 4             476               21                8.92                 1.15
#
#    energy_consumption_kwh  profit  defect_rate
# 0                    1028   12286     0.019139
# 1                    1038   18279     0.053156
# 2                    1084   23261     0.058559
# 3                    1144   11674     0.046414
# 4                    1349   12045     0.044118

# %% [markdown]
# # Q11. Using groupby().apply(), find the profit range (max − min) for each factory.

# %%
df.groupby('factory').apply(lambda x:x['profit'].max()-x['profit'].min())
# Out:
# /tmp/ipykernel_8727/4187880936.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('factory').apply(lambda x:x['profit'].max()-x['profit'].min())
# factory
# Plant_A    14199
# Plant_B    14349
# Plant_C    12745
# dtype: int64

# %% [markdown]
# # Q12. Using groupby().apply(), find the row with maximum units_produced in each product_category.

# %%
df.groupby('product_category').apply(lambda x: x["units_produced"].idxmax)
# Out:
# /tmp/ipykernel_8727/3408788537.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('product_category').apply(lambda x: x["units_produced"].idxmax)
# product_category
# Automotive     <bound method Series.idxmax of 0     627\n1   ...
# Electronics    <bound method Series.idxmax of 2     666\n3   ...
# Furniture      <bound method Series.idxmax of 4     476\n6   ...
# dtype: object

# %% [markdown]
# # Use apply() to create a new column efficency_score:
# ### effcincy=units_produced/production_time_

# %%
df["efficency_score"]=df.apply(lambda x:x['units_produced']/x['production_time_hr'],axis=1)
df.head()
# Out:
#    production_id product_category  factory    shift supervisor  \
# 0            101       Automotive  Plant_A    Night         S1
# 1            102       Automotive  Plant_A    Night         S2
# 2            103      Electronics  Plant_A    Night         S4
# 3            104      Electronics  Plant_B  Morning         S3
# 4            105        Furniture  Plant_A    Night         S3
#
#    units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0             627               12                6.58                 0.56
# 1             602               32                6.60                 0.32
# 2             666               39                7.76                 0.78
# 3             474               22                6.97                 1.44
# 4             476               21                8.92                 1.15
#
#    energy_consumption_kwh  profit  defect_rate  efficency_score
# 0                    1028   12286     0.019139        95.288754
# 1                    1038   18279     0.053156        91.212121
# 2                    1084   23261     0.058559        85.824742
# 3                    1144   11674     0.046414        68.005739
# 4                    1349   12045     0.044118        53.363229

# %% [markdown]
# # Q14. Find how many times each product_category appears in the dataset.

# %%
df.groupby('product_category').size()
# Out:
# product_category
# Automotive     18
# Electronics    16
# Furniture      16
# dtype: int64

# %% [markdown]
# # Q15. Count the number of records for each shift.

# %%
df.groupby('shift').size()
# Out:
# shift
# Evening     7
# Morning    22
# Night      21
# dtype: int64

# %% [markdown]
# # Q16. Find the most frequent supervisor using value_counts().

# %%
df['supervisor'].value_counts().head(1)
# Out:
# supervisor
# S3    15
# Name: count, dtype: int64

# %% [markdown]
# # Q17. Sort the dataset by profit in descending order.

# %%
df.sort_values(by='profit',ascending=False)
# Out:
#     production_id product_category  factory    shift supervisor  \
# 31            132       Automotive  Plant_A    Night         S1
# 36            137      Electronics  Plant_C    Night         S2
# 9             110       Automotive  Plant_B  Morning         S4
# 14            115       Automotive  Plant_B    Night         S2
# 27            128        Furniture  Plant_A  Morning         S4
# 43            144        Furniture  Plant_A  Morning         S4
# 2             103      Electronics  Plant_A    Night         S4
# 42            143        Furniture  Plant_C    Night         S2
# 8             109      Electronics  Plant_A  Morning         S3
# 18            119      Electronics  Plant_A    Night         S4
# 13            114        Furniture  Plant_C  Evening         S1
# 29            130       Automotive  Plant_A    Night         S3
# 37            138       Automotive  Plant_B    Night         S4
# 48            149       Automotive  Plant_C    Night         S2
# 5             106      Electronics  Plant_B  Morning         S2
# 49            150        Furniture  Plant_C  Morning         S3
# 41            142       Automotive  Plant_A  Morning         S2
# 35            136       Automotive  Plant_C  Morning         S3
# 21            122      Electronics  Plant_A  Morning         S1
# 23            124        Furniture  Plant_A  Evening         S4
# 10            111       Automotive  Plant_B    Night         S4
# 22            123      Electronics  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 45            146        Furniture  Plant_C    Night         S3
# 15            116       Automotive  Plant_A  Morning         S3
# 1             102       Automotive  Plant_A    Night         S2
# 33            134        Furniture  Plant_A  Morning         S4
# 26            127       Automotive  Plant_A  Morning         S1
# 20            121       Automotive  Plant_B  Morning         S2
# 24            125        Furniture  Plant_C  Morning         S1
# 47            148       Automotive  Plant_A  Evening         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 40            141      Electronics  Plant_B  Morning         S2
# 32            133        Furniture  Plant_A    Night         S3
# 28            129        Furniture  Plant_C    Night         S4
# 46            147      Electronics  Plant_A    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 7             108      Electronics  Plant_B  Evening         S3
# 17            118      Electronics  Plant_A    Night         S1
# 19            120       Automotive  Plant_C    Night         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 30            131      Electronics  Plant_C  Morning         S2
# 0             101       Automotive  Plant_A    Night         S1
# 34            135        Furniture  Plant_A  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 39            140      Electronics  Plant_C  Morning         S1
# 3             104      Electronics  Plant_B  Morning         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 44            145       Automotive  Plant_A  Evening         S3
# 16            117       Automotive  Plant_B  Evening         S1
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 31             335                9                8.53                 0.51
# 36             639               11                9.32                 0.37
# 9              505               22                6.70                 1.39
# 14             450               32                6.97                 0.20
# 27             347               20                7.00                 0.83
# 43             436               15                8.86                 0.34
# 2              666               39                7.76                 0.78
# 42             390               31                6.57                 1.16
# 8              627               40                7.16                 0.62
# 18             343               36                8.95                 1.47
# 13             583                5                8.54                 0.35
# 29             379               17                7.39                 1.46
# 37             439               23                8.31                 1.13
# 48             662               32                6.51                 1.40
# 5              621               28                8.23                 1.12
# 49             486               32                6.71                 1.06
# 41             641               11                7.56                 0.93
# 35             445               15                7.81                 0.91
# 21             415                9                7.51                 0.96
# 23             409               39                6.90                 1.42
# 10             502               34                6.93                 0.38
# 22             417                9                9.22                 1.32
# 11             598               30                7.59                 1.50
# 45             442                9                9.40                 0.56
# 15             559               11                9.11                 0.59
# 1              602               32                6.60                 0.32
# 33             422               21                7.69                 1.07
# 26             371               32                7.05                 0.80
# 20             665               24                7.70                 1.07
# 24             397               11                6.79                 0.76
# 47             476               25                7.81                 1.48
# 12             378               15                8.88                 0.75
# 40             489               40                6.94                 0.37
# 32             617               10                7.76                 0.96
# 28             301               29                7.30                 1.22
# 46             314               12                9.13                 0.54
# 25             331               30                8.68                 1.24
# 7              659                9                8.33                 0.42
# 17             357               28                9.14                 1.28
# 19             581               15                7.30                 1.33
# 6              351               29                7.33                 1.03
# 30             329                8                8.25                 0.85
# 0              627               12                6.58                 0.56
# 34             618               11                6.72                 0.48
# 4              476               21                8.92                 1.15
# 39             382               33                8.16                 0.76
# 3              474               22                6.97                 1.44
# 38             428                8                6.78                 0.75
# 44             479               24                8.96                 1.33
# 16             690               15                8.12                 1.21
#
# 35            136       Automotive  Plant_C  Morning         S3
# 37            138       Automotive  Plant_B    Night         S4
# 29            130       Automotive  Plant_A    Night         S3
# 26            127       Automotive  Plant_A  Morning         S1
# 31            132       Automotive  Plant_A    Night         S1
# 2             103      Electronics  Plant_A    Night         S4
# 7             108      Electronics  Plant_B  Evening         S3
# 36            137      Electronics  Plant_C    Night         S2
# 8             109      Electronics  Plant_A  Morning         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 40            141      Electronics  Plant_B  Morning         S2
# 3             104      Electronics  Plant_B  Morning         S3
# 38            139      Electronics  Plant_B  Morning         S3
# 22            123      Electronics  Plant_B    Night         S4
# 21            122      Electronics  Plant_A  Morning         S1
# 39            140      Electronics  Plant_C  Morning         S1
# 17            118      Electronics  Plant_A    Night         S1
# 18            119      Electronics  Plant_A    Night         S4
# 25            126      Electronics  Plant_A    Night         S4
# 30            131      Electronics  Plant_C  Morning         S2
# 46            147      Electronics  Plant_A    Night         S4
# 34            135        Furniture  Plant_A  Morning         S3
# 32            133        Furniture  Plant_A    Night         S3
# 11            112        Furniture  Plant_A  Morning         S1
# 13            114        Furniture  Plant_C  Evening         S1
# 49            150        Furniture  Plant_C  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 45            146        Furniture  Plant_C    Night         S3
# 43            144        Furniture  Plant_A  Morning         S4
# 33            134        Furniture  Plant_A  Morning         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 24            125        Furniture  Plant_C  Morning         S1
# 42            143        Furniture  Plant_C    Night         S2
# 12            113        Furniture  Plant_C  Evening         S3
# 6             107        Furniture  Plant_B  Morning         S3
# 27            128        Furniture  Plant_A  Morning         S4
# 28            129        Furniture  Plant_C    Night         S4
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 16             690               15                8.12                 1.21
# 20             665               24                7.70                 1.07
# 48             662               32                6.51                 1.40
# 41             641               11                7.56                 0.93
# 0              627               12                6.58                 0.56
# 1              602               32                6.60                 0.32
# 19             581               15                7.30                 1.33
# 15             559               11                9.11                 0.59
# 9              505               22                6.70                 1.39
# 10             502               34                6.93                 0.38
# 44             479               24                8.96                 1.33
# 47             476               25                7.81                 1.48
# 14             450               32                6.97                 0.20
# 35             445               15                7.81                 0.91
# 37             439               23                8.31                 1.13
# 29             379               17                7.39                 1.46
# 26             371               32                7.05                 0.80
# 31             335                9                8.53                 0.51
# 2              666               39                7.76                 0.78
# 7              659                9                8.33                 0.42
# 36             639               11                9.32                 0.37
# 8              627               40                7.16                 0.62
# 5              621               28                8.23                 1.12
# 40             489               40                6.94                 0.37
# 3              474               22                6.97                 1.44
# 38             428                8                6.78                 0.75
# 22             417                9                9.22                 1.32
# 21             415                9                7.51                 0.96
# 39             382               33                8.16                 0.76
# 17             357               28                9.14                 1.28
# 18             343               36                8.95                 1.47
# 25             331               30                8.68                 1.24
csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            996 non-null    object
#  5   gender                   995 non-null    object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
#  14  cogs                     1000 non-null   float64
#  15  gross margin percentage  1000 non-null   float64
#  16  gross income             996 non-null    float64
#  17  rating                   1000 non-null   float64
#  18  day_of_week              1000 non-null   object
# dtypes: float64(7), int64(2), object(10)
# memory usage: 148.6+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# invoice id                 0
# branch                     0
# city                       0
# customer type              4
# gender                     5
# product line               0
# unit price                 0
# quantity                   0
# tax 5%                     0
# total                      0
# date                       0
# time                       0
# payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               4
# rating                     0
# day_of_week                0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df['customer type'].fillna(df['customer type'].mode()[0],inplace=True)
df['gender'].fillna(df['gender'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_8727/1779643077.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customer type'].fillna(df['customer type'].mode()[0],inplace=True)
# /tmp/ipykernel_8727/1779643077.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].fillna(df['gender'].mode()[0],inplace=True)

# %%
df.groupby('branch')['gross income'].sum()
# Out:
# branch
# A    5057.160500
# B    5064.615727
# C    5289.837227
# Name: gross income, dtype: float64

# %%
df['product line'].value_counts().head()
# Out:
# product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Name: count, dtype: int64

# %%
df.groupby('branch')['rating'].mean()
# Out:
# branch
# A    7.026536
# B    6.822735
# C    7.072866
# Name: rating, dtype: float64

# %%
df.groupby('payment',as_index=False).size().sort_values(by='size').tail(1)
# Out:
#    payment  size
# 2  Ewallet   345

# %%
df['day_of_week']
# Out:
# 0      Saturday
# 1        Friday
# 2        Sunday
# 3        Sunday
# 4        Friday
#          ...
# 995     Tuesday
# 996    Saturday
# 997    Saturday
# 998      Friday
# 999      Monday
# Name: day_of_week, Length: 1000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            1000 non-null   object
#  5   gender                   1000 non-null   object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
#  14  cogs                     1000 non-null   float64
#  15  gross margin percentage  1000 non-null   float64
#  16  gross income             1000 non-null   float64
#  17  rating                   1000 non-null   float64
#  18  day_of_week              1000 non-null   object
# dtypes: float64(7), int64(2), object(10)
# memory usage: 148.6+ KB
