# %%
import pandas as pd
import numpy as np

# %%
x = ["A","B","C","D","E"]
ser = pd.Series(x)
print(ser)
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# dtype: object

# %%
a = [10,25,36,14]
ser = pd.Series(a, name= "marks",index =["python-2","FSD-2","COA","DM"])
print(ser)
print(ser.ndim)
print(type(ser))
# Out:
# python-2    10
# FSD-2       25
# COA         36
# DM          14
# Name: marks, dtype: int64
# 1
# <class 'pandas.core.series.Series'>

# %%
# while using any data is None datatype will chnage
# if you adding index then if index name and key of dic not match then it put NaN
# if you adding index then only Index element will printed
A = {
    "FSD":25,
    "PY-2":36,
    "COA":None,
    "Dm":10
}
ser = pd.Series(A,index = ["FSD","PY-2","COA","tOC","Dm"])
print(ser)
# Out:
# FSD     25.0
# PY-2    36.0
# COA      NaN
# tOC      NaN
# Dm      10.0
# dtype: float64

# %%
marks = pd.read_csv("Book1.csv")
print(marks)
print(type(marks))
ser = marks["Marks "]
print(ser)
# min ,max, mode , meadian , size , shape
print(ser.min())
print(ser.max())
print(ser.mean())
print(ser.median())
print(ser.mode())
print(ser.size)
print(ser.shape[0])
# Out:
#    Marks
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# <class 'pandas.core.frame.DataFrame'>
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks , dtype: int64
# 10
# 50
# 30.0
# 30.0
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks , dtype: int64
# 5
# 5

# %%
data = {
    'Mname': ["A","B","C","D"],
    'Marks' : [25,34,35,20],
    'grade' : ['C','B','B','A']

}
df = pd.DataFrame(data)
print(df.shape) # print dimensions
print(df.shape[0]) # print rows
print(df.shape[1]) # print cols (only for data frame)
print(df)
# Out:
# (4, 3)
# 4
# 3
#   Mname  Marks grade
# 0     A     25     C
# 1     B     34     B
# 2     C     35     B
# 3     D     20     A

# %%
data = [
    [100,80,15],
    [25,25,23],
    [120,80,14],
    [80,50,20]
]
df =pd.DataFrame(data,columns=["A","B","C"])
df
df1 = df.set_index('A')
print(df1)
print(df)
# Out:
#       B   C
# A
# 100  80  15
# 25   25  23
# 120  80  14
# 80   50  20
#      A   B   C
# 0  100  80  15
# 1   25  25  23
# 2  120  80  14
# 3   80  50  20

# %%
data = [
    [100,80,15],
    [25,25,23],
    [120,80,14],
    [80,50,20]
]
df =pd.DataFrame(data,columns=["A","B","C"])
df
df.set_index('A',inplace =True)
print(df)
# Out:
#       B   C
# A
# 100  80  15
# 25   25  23
# 120  80  14
# 80   50  20

# %%
df = pd.read_csv("ipl-matches.csv")
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# if pass 10 then show 10 rows
df.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
# same as head but show last
# if pass outof index show as full csv
df.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# shows default int and flot value 
# INCLUDES / select data or columns
# PERCENTILES GIVE Median vaules at that points
df.describe(percentiles=[0.20,0.40,0.60])
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 20%    5.012128e+05    5.000000
# 40%    5.980556e+05    7.000000
# 50%    8.297380e+05    8.000000
# 60%    9.810058e+05    9.000000
# max    1.312200e+06  146.000000

# %%
data = [
    
        {"name": "A","age":17,"gender": "M"},
        {"name": "B","age":19,"gender": "F"},
        {"name": "C","age":18,"gender": "M"}
    
    ]
df = pd.DataFrame(data)
df
# Out:
#   name  age gender
# 0    A   17      M
# 1    B   19      F
# 2    C   18      M

# %%
# pass index of row,column
print(df.iloc[:,:])
# Out:
#   name  age gender
# 0    A   17      M
# 1    B   19      F
# 2    C   18      M

# %%
df.iloc[0:2,1]
# Out:
# 0    17
# 1    19
# Name: age, dtype: int64

# %%
df.iloc[1:2,1:2]
# Out:
#    age
# 1   19

# %%
df.iloc[1:4,1:4]
# Out:
#    age gender
# 1   19      F
# 2   18      M

# %%
df.iloc[1,[0,2]]
# Out:
# name      B
# gender    F
# Name: 1, dtype: object

# %%
df.iloc[[True,False,True],:]
# Out:
#   name  age gender
# 0    A   17      M
# 2    C   18      M

# %%
df
# Out:
#   name  age gender
# 0    A   17      M
# 1    B   19      F
# 2    C   18      M

# %%
# give row ,column name(lable)
df.loc[0,"age"]
# Out:
# np.int64(17)

# %%
df.loc[0:2,"name":"gender"]
# Out:
#   name  age gender
# 0    A   17      M
# 1    B   19      F
# 2    C   18      M

# %%
df.loc[1,"name":"gender"]
# Out:
# name       B
# age       19
# gender     F
# Name: 1, dtype: object

# %%
df.loc[(df["age"]>=18) & (df["gender"]=="M")]
# Out:
#   name  age gender
# 2    C   18      M

# %%
df = pd.read_csv("imdb-top-1000.csv")
df
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
df.loc[(df["IMDB_Rating"]>=8.3)& (df["Released_Year"]>=2010)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.loc[(df["IMDB_Rating"]>=8.3)& (df["Released_Year"]>=2010)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
df["Released_Year"].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
df.loc[df["Released_Year"]=="PG","Released_Year"]=0

# %%
df["Released_Year"].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 0], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
df["Released_Year"]= df["Released_Year"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   int64
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
df.loc[(df["IMDB_Rating"]>=8.0)& (df["Released_Year"]>2010)].shape[0]
# Out:
# 99

# %%
df["Released_Year"].value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1920     1
# 1930     1
# 1922     1
# 1943     1
# 0        1
# Name: count, Length: 100, dtype: int64

# %%
df["Released_Year"].nunique()
# Out:
# 100

# %%
df["Released_Year"].value_counts(ascending=True)
# Out:
# Released_Year
# 1936     1
# 1943     1
# 1920     1
# 1930     1
# 1937     1
#         ..
# 2013    28
# 2016    28
# 2009    29
# 2004    31
# 2014    32
# Name: count, Length: 100, dtype: int64

# %%
data = [
    [10,20,12,5,1],
    [20,22,12,15,12],
    [12,12,12,32,12],
    [12,14,12,35,21]
]
df = pd.DataFrame(data)
df
# Out:
#     0   1   2   3   4
# 0  10  20  12   5   1
# 1  20  22  12  15  12
# 2  12  12  12  32  12
# 3  12  14  12  35  21

# %%
print(df.mean())
print(df.median())
print(df.sum())
print(df.count())
print(df.mode())
print(df.max())
# Out:
# 0    13.50
# 1    17.00
# 2    12.00
# 3    21.75
# 4    11.50
# dtype: float64
# 0    12.0
# 1    17.0
# 2    12.0
# 3    23.5
# 4    12.0
# dtype: float64
# 0    54
# 1    68
# 2    48
# 3    87
# 4    46
# dtype: int64
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64
#       0   1     2   3     4
# 0  12.0  12  12.0   5  12.0
# 1   NaN  14   NaN  15   NaN
# 2   NaN  20   NaN  32   NaN
# 3   NaN  22   NaN  35   NaN
# 0    20
# 1    22
# 2    12
# 3    35
# 4    21
# dtype: int64

# %%
data = {
    "A": [1,2,np.nan,np.nan,3],
    "B": [np.nan,3,4,5,np.nan],
    "C": [np.nan,np.nan,6,7,8],
    "D": [4,7,3,2,1],
    "E": [1,np.nan,3,np.nan,np.nan]
}
df = pd.DataFrame(data)
df
# Out:
#      A    B    C  D    E
# 0  1.0  NaN  NaN  4  1.0
# 1  2.0  3.0  NaN  7  NaN
# 2  NaN  4.0  6.0  3  3.0
# 3  NaN  5.0  7.0  2  NaN
# 4  3.0  NaN  8.0  1  NaN

# %%
df.isnull().any()
# Out:
# A     True
# B     True
# C     True
# D    False
# E     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# A    2
# B    2
# C    2
# D    0
# E    3
# dtype: int64

# %%
#fill mean vault 
df.fillna(df.mean())
# Out:
#      A    B    C  D    E
# 0  1.0  4.0  7.0  4  1.0
# 1  2.0  3.0  7.0  7  2.0
# 2  2.0  4.0  6.0  3  3.0
# 3  2.0  5.0  7.0  2  2.0
# 4  3.0  4.0  8.0  1  2.0

# %%
df
# Out:
#      A    B    C  D    E
# 0  1.0  NaN  NaN  4  1.0
# 1  2.0  3.0  NaN  7  NaN
# 2  NaN  4.0  6.0  3  3.0
# 3  NaN  5.0  7.0  2  NaN
# 4  3.0  NaN  8.0  1  NaN

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
# dropna axis=1 will keep only not null column
df.dropna(axis=1)
# Out:
#    D
# 0  4
# 1  7
# 2  3
# 3  2
# 4  1

# %%
df.dropna(how="all")
# Out:
#      A    B    C  D    E
# 0  1.0  NaN  NaN  4  1.0
# 1  2.0  3.0  NaN  7  NaN
# 2  NaN  4.0  6.0  3  3.0
# 3  NaN  5.0  7.0  2  NaN
# 4  3.0  NaN  8.0  1  NaN

# %%
df.dropna(subset=["A","B"])
# Out:
#      A    B   C  D   E
# 1  2.0  3.0 NaN  7 NaN

# %%
df
# Out:
#      A    B    C  D    E
# 0  1.0  NaN  NaN  4  1.0
# 1  2.0  3.0  NaN  7  NaN
# 2  NaN  4.0  6.0  3  3.0
# 3  NaN  5.0  7.0  2  NaN
# 4  3.0  NaN  8.0  1  NaN

# %%
# if vault of not null vaule grater then some enterd vault values
df.dropna(thresh=4)
# Out:
#     A    B    C  D    E
# 2 NaN  4.0  6.0  3  3.0

# %%
df.drop??
# Out:
# Signature:
# df.drop(
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise',
# ) -> 'DataFrame | None'
# Source:
#     def drop(
#         self,
#         labels: IndexLabel | None = None,
#         *,
#         axis: Axis = 0,
#         index: IndexLabel | None = None,
#         columns: IndexLabel | None = None,
#         level: Level | None = None,
#         inplace: bool = False,
#         errors: IgnoreRaise = "raise",
#     ) -> DataFrame | None:
#         """
#         Drop specified labels from rows or columns.
#
#         Remove rows or columns by specifying label names and corresponding
#         axis, or by directly specifying index or column names. When using a
#         multi-index, labels on different levels can be removed by specifying
# ...

# %%
df.drop(1)
# Out:
#      A    B    C  D    E
# 0  1.0  NaN  NaN  4  1.0
# 2  NaN  4.0  6.0  3  3.0
# 3  NaN  5.0  7.0  2  NaN
# 4  3.0  NaN  8.0  1  NaN

# %%
df.drop("A",axis=1)
# Out:
#      B    C  D    E
# 0  NaN  NaN  4  1.0
# 1  3.0  NaN  7  NaN
# 2  4.0  6.0  3  3.0
# 3  5.0  7.0  2  NaN
# 4  NaN  8.0  1  NaN

# %% [markdown]
# # duplicate values

# %%
data = [
    [1,1,2,3,4],
    [3,3,4,2,5],
    [4,5,9,4,6],
    [1,1,2,3,4],
    [3,3,4,2,5],
    [1,1,2,2,4]
]
df = pd.DataFrame(data)
df
# Out:
#    0  1  2  3  4
# 0  1  1  2  3  4
# 1  3  3  4  2  5
# 2  4  5  9  4  6
# 3  1  1  2  3  4
# 4  3  3  4  2  5
# 5  1  1  2  2  4

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
df.duplicated(keep="last")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.duplicated(subset=[0,1,2])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    0  1  2  3  4
# 0  1  1  2  3  4
# 1  3  3  4  2  5
# 2  4  5  9  4  6
# 5  1  1  2  2  4

# %%
df.drop_duplicates(keep="last")
# Out:
#    0  1  2  3  4
# 2  4  5  9  4  6
# 3  1  1  2  3  4
# 4  3  3  4  2  5
# 5  1  1  2  2  4

# %%
df.drop_duplicates(subset=[0,1,2])
# Out:
#    0  1  2  3  4
# 0  1  1  2  3  4
# 1  3  3  4  2  5
# 2  4  5  9  4  6

# %%
df.drop_duplicates(keep="last",inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#    0  1  2  3  4
# 0  4  5  9  4  6
# 1  1  1  2  3  4
# 2  3  3  4  2  5
# 3  1  1  2  2  4

# %%
df = pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df["horsepower"].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df=df.loc[df["horsepower"]!="?"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    object
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 30.6+ KB

# %%
df["horsepower"]=df["horsepower"].astype("int")
# Out:
# C:\Users\vdp87\AppData\Local\Temp\ipykernel_17496\3409201512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"]=df["horsepower"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model year    392 non-null    int64
#  7   origin        392 non-null    int64
#  8   car name      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
import seaborn as sns

# %%
sns.boxplot(data=df["acceleration"])
# Out:
# <Axes: ylabel='acceleration'>

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
# removing out lyers
q1 = df["acceleration"].quantile(0.25)
q3 = df["acceleration"].quantile(0.75)
iqr = q3-q1
ur = q3+1.5*iqr
lr = q1-1.5*iqr
df = df.loc[(df["acceleration"]>lr)& (df["acceleration"]<ur)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           381 non-null    float64
#  1   cylinders     381 non-null    int64
#  2   displacement  381 non-null    float64
#  3   horsepower    381 non-null    int64
#  4   weight        381 non-null    int64
#  5   acceleration  381 non-null    float64
#  6   model year    381 non-null    int64
#  7   origin        381 non-null    int64
#  8   car name      381 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 29.8+ KB

# %%
sns.boxplot(data=df["acceleration"])
# upder points are removed called ascalration points
# Out:
# <Axes: ylabel='acceleration'>

# %%
sns.boxplot(data =df['cylinders'])
# Out:
# <Axes: ylabel='cylinders'>

# %%
sns.boxplot(data =df["horsepower"])
# Out:
# <Axes: ylabel='horsepower'>

# %%
q1 = df["horsepower"].quantile(0.25)
q3 = df["horsepower"].quantile(0.75)
iqr=q3-q1
ur = q3+1.5*iqr
lr = q1-1.5*iqr
df = df.loc[(df["horsepower"]>lr)& (df["horsepower"]<ur)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           371 non-null    float64
#  1   cylinders     371 non-null    int64
#  2   displacement  371 non-null    float64
#  3   horsepower    371 non-null    int64
#  4   weight        371 non-null    int64
#  5   acceleration  371 non-null    float64
#  6   model year    371 non-null    int64
#  7   origin        371 non-null    int64
#  8   car name      371 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 29.0+ KB

# %%
sns.boxplot(data=df["horsepower"])
# Out:
# <Axes: ylabel='horsepower'>

# %% [markdown]
# # Scatter matrix

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df,figsize=(20,20),alpha=0.5)
plt.show()

# %%
# parallel coordinates

# %%
pd.plotting.parallel_coordinates(df,class_column='cylinders',cols=['mpg','acceleration',"origin"],color = ['red','blue','yellow','orange','green'])
plt.show()

# %% [markdown]
# # Cross tabulation

# %%
pd.crosstab(df["model year"],df["cylinders"],margins=True)
# Out:
# cylinders   3    4  5   6   8  All
# model year
# 70          0    7  0   4   9   20
# 71          0   12  0   8   7   27
# 72          1   13  0   0  12   26
# 73          1   11  0   8  17   37
# 74          0   15  0   6   5   26
# 75          0   12  0  12   6   30
# 76          0   12  0  10   9   31
# 77          1   14  0   5   8   28
# 78          0   17  1  12   6   36
# 79          0   11  1   6   9   27
# 80          1   22  1   2   0   26
# 81          0   20  0   7   1   28
# 82          0   26  0   3   0   29
# All         4  192  3  83  89  371

# %% [markdown]
# # co-relation between numerical columns

# %%
df.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.772108     -0.806390   -0.789896 -0.830728
# cylinders    -0.772108   1.000000      0.955822    0.858374  0.897613
# displacement -0.806390   0.955822      1.000000    0.890800  0.940377
# horsepower   -0.789896   0.858374      0.890800    1.000000  0.882190
# weight       -0.830728   0.897613      0.940377    0.882190  1.000000
# acceleration  0.376035  -0.475441     -0.489770   -0.658070 -0.383030
# model year    0.548487  -0.300111     -0.311893   -0.346579 -0.262423
# origin        0.563058  -0.561004     -0.621416   -0.464094 -0.585646
#
#               acceleration  model year    origin
# mpg               0.376035    0.548487  0.563058
# cylinders        -0.475441   -0.300111 -0.561004
# displacement     -0.489770   -0.311893 -0.621416
# horsepower       -0.658070   -0.346579 -0.464094
# weight           -0.383030   -0.262423 -0.585646
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# # Replace value

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.replace('chevrolet chevelle malibu','Car')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0          90    2950          17.3
# 393  27.0          4         140.0          86    2790          15.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin            car name
# 0            70       1                 Car
# 1            70       1   buick skylark 320
# ...

# %% [markdown]
# # PB 64

# %%
data = pd.read_csv("car data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.head(301)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#1
data.loc[(data["Kms_Driven"]>30000)& (data["Car_Name"]=="ritz")].shape[0]
# Out:
# 3

# %%
#2
data.loc[(data["Selling_Price"]>10)& (data["Year"]==2017)&(data["Fuel_Type"]=="Petrol")].shape[0]
# Out:
# 2

# %%
#3
data.loc[(data["Car_Name"]=="swift")&(data["Selling_Price"]<4)].shape[0]
# Out:
# 1

# %%
#4
data.loc[(data["Selling_Price"]>10)& (data["Year"]==2015)&(data["Fuel_Type"]=="Petrol")&(data["Transmission"]=="Automatic")].shape[0]
# Out:
# 1

# %%
#5
data.loc[(data["Selling_Price"]<1)& (data["Transmission"]=="Automatic")]
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155    Honda Activa 4G  2017           0.48           0.51        4300
# 159    Honda Activa 4G  2017           0.45           0.51        4000
# 165          Activa 3g  2016           0.45           0.54         500
# 173          Activa 4g  2017           0.40           0.51        1300
# 177   Honda Activa 125  2016           0.35           0.57       24000
# 178        TVS Jupyter  2014           0.35           0.52       19000
# 185  Suzuki Access 125  2008           0.25           0.58        1900
# 186           TVS Wego  2010           0.25           0.52       22000
# 196          Activa 3g  2008           0.17           0.52      500000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 155    Petrol  Individual    Automatic      0
# 159    Petrol  Individual    Automatic      0
# 165    Petrol  Individual    Automatic      0
# 173    Petrol  Individual    Automatic      0
# ...

# %%
#6
data.loc[(data["Year"]<=2015)& (data["Year"]>=2010)&(data["Fuel_Type"]=="Petrol" )&(data["Kms_Driven"]>50000)].shape[0]
# Out:
# 23

# %%
#7
data.loc[(data["Present_Price"]-data["Selling_Price"])>15]
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50       fortuner  2012          14.90          30.61      104707    Diesel
# 59       fortuner  2014          19.99          35.96       41000    Diesel
# 62       fortuner  2014          18.75          35.96       78000    Diesel
# 78  corolla altis  2010           5.25          22.83       80000    Petrol
# 79       fortuner  2012          14.50          30.61       89000    Diesel
# 85          camry  2006           2.50          23.73      142000    Petrol
# 86   land cruiser  2010          35.00          92.60       78000    Diesel
# 94  corolla altis  2008           4.00          22.78       89000    Petrol
#
#    Seller_Type Transmission  Owner
# 50      Dealer    Automatic      0
# 59      Dealer    Automatic      0
# 62      Dealer    Automatic      0
# 78      Dealer    Automatic      0
# 79      Dealer    Automatic      0
# 85  Individual    Automatic      3
# ...

# %%
#8
data.loc[(data["Kms_Driven"]<5000)& (data["Selling_Price"]<50000)].shape[0]
# Out:
# 22

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 67

# %%
df=pd.read_csv("ipl-matches.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
# How many matches were won by Gujarat Titans in a Super Over ?
df.loc[(df["WinningTeam"]=="Gujarat Titans") & (df['SuperOver']=="Y")].shape[0]
# Out:
# 0

# %%
#2.How Many Matches won by Royal Challengers Bangalore Vs Kolkata Knight Riders
df.loc[(df["WinningTeam"]=="Royal Challengers Bangalore") & ((df["Team1"]=="Kolkata Knight Riders")|(df["Team2"]=="Kolkata Knight Riders"))].shape[0]
# Out:
# 14

# %%
#3.How many Matches won by Toss Winner of the Match.
df.loc[df['TossWinner']==df['WinningTeam']].shape[0]
# Out:
# 489

# %%
#4.In how many matches was the result decided by the D/L method and the match was won by wickets
df.loc[(df["method"]=="D/L")&(df["WonBy"]=="Wickets")].shape[0]
# Out:
# 8

# %%
#5.In how many matches Toss won by Rajasthan Royals & Won the Match.
df.loc[(df['TossWinner']=="Rajasthan Royals")&(df['WinningTeam']=="Rajasthan Royals") ].shape[0]
# Out:
# 49

# %%
#6.In how many matches V Kohli declared player of the match against Chennai Super Kings
df.loc[((df["Team1"]=="Chennai Super Kings")|(df["Team2"]=="Chennai Super Kings"))& (df["Player_of_Match"]=="V Kohli")].shape[0]
# Out:
# 2

# %%
#7.Which Team is the Toss Winner of the Final match Played in Dubai?
df.loc[(df["MatchNumber"]=="Final")&(df["City"]=="Dubai")]["TossWinner"]
# Out:
# 74    Kolkata Knight Riders
# Name: TossWinner, dtype: object

# %%
#8.List out the Finals played by Kolkata Knight Riders in which Toss Won by Kolkata Knight Riders in the Finals and choose to field.
df.loc[(df["MatchNumber"]=="Final")&(df['TossWinner']=="Kolkata Knight Riders")&(df['TossDecision']=="field")]
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 74   1254117      Dubai  2021-10-15   2021       Final    Chennai Super Kings
# 492   734049  Bangalore  2014-06-01   2014       Final  Kolkata Knight Riders
#
#                      Team2                                Venue  \
# 74   Kolkata Knight Riders  Dubai International Cricket Stadium
# 492        Kings XI Punjab                M Chinnaswamy Stadium
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# 74   Kolkata Knight Riders        field         N    Chennai Super Kings
# 492  Kolkata Knight Riders        field         N  Kolkata Knight Riders
#
#        WonBy  Margin method Player_of_Match  \
# 74      Runs    27.0    NaN    F du Plessis
# 492  Wickets     3.0    NaN       MK Pandey
#
#                                           Team1Players  \
# 74   ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 492  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
#
# ...

# %%
data = {
    "Name":['A','B','C'],
    'Marks':[50,60,70],
    'Percent':[70,80,90]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks  Percent
# 0    A     50       70
# 1    B     60       80
# 2    C     70       90

# %%
df['new']=[10,20,30]

# %%
df
# Out:
#   Name  Marks  Percent  new
# 0    A     50       70   10
# 1    B     60       80   20
# 2    C     70       90   30

# %% [markdown]
# # Apply ,  Concat,Merge,Groupby

# %%
df
# Out:
#   Name  Marks  Percent  new
# 0    A     50       70   10
# 1    B     60       80   20
# 2    C     70       90   30

# %%
df.apply??
# Out:
# Signature:
# df.apply(
#     func: 'AggFuncType',
#     axis: 'Axis' = 0,
#     raw: 'bool' = False,
#     result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None,
#     args=(),
#     by_row: "Literal[False, 'compat']" = 'compat',
#     engine: "Literal['python', 'numba']" = 'python',
#     engine_kwargs: 'dict[str, bool] | None' = None,
#     **kwargs,
# )
# Source:
#     def apply(
#         self,
#         func: AggFuncType,
#         axis: Axis = 0,
#         raw: bool = False,
#         result_type: Literal["expand", "reduce", "broadcast"] | None = None,
#         args=(),
#         by_row: Literal[False, "compat"] = "compat",
#         engine: Literal["python", "numba"] = "python",
#         engine_kwargs: dict[str, bool] | None = None,
#         **kwargs,
#     ):
#         """
#         Apply a function along an axis of the DataFrame.
#
#         Objects passed to the function are Series objects whose index is
# ...

# %% [markdown]
# ## type of function in this is inbuilt,user difine and lemda function

# %%
df.apply(np.sum)
# Out:
# Name       ABC
# Marks      180
# Percent    240
# new         60
# dtype: object

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#       Marks  Percent  new
# Name
# A        50       70   10
# B        60       80   20
# C        70       90   30

# %%
df.apply(sum,axis=1)
# Out:
# Name
# A    130
# B    160
# C    190
# dtype: int64

# %%
df.apply(lambda x:x+5)
# Out:
#       Marks  Percent  new
# Name
# A        55       75   15
# B        65       85   25
# C        75       95   35

# %%
df['Percent'].apply(lambda x:'Pass' if x>75 else "Fail")
# Out:
# Name
# A    Fail
# B    Pass
# C    Pass
# Name: Percent, dtype: object

# %%
df
# Out:
#       Marks  Percent  new
# Name
# A        50       70   10
# B        60       80   20
# C        70       90   30

# %%
df["Marks_Extra"]=df['Marks'].apply(lambda x: x+4 if x>60 else x)

# %%
df
# Out:
#       Marks  Percent  new  Marks_Extra
# Name
# A        50       70   10           50
# B        60       80   20           60
# C        70       90   30           74

# %%
def grade(x):
    if x>70:
        
    elif x>55:
        return 'B'
    else :
        return 'C'
grade(56)
# Out:
#   Cell In[128], line 4
#     elif x>55:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
def grade(x):
    if x["Marks_Extra"]>70:
        return 'A'
    elif x["Marks_Extra"]>55:
        return 'B'
    else :
        return 'C'
df["Grade"]=df.apply(grade,axis=1)

# %%
df
# Out:
#       Marks  Percent  new  Marks_Extra Grade
# Name
# A        50       70   10           50     C
# B        60       80   20           60     B
# C        70       90   30           74     A

# %%
for i in df:
    print(i)
# Out:
# Marks
# Percent
# new
# Marks_Extra
# Grade

# %%
for i in df.values:
    print(i)
# Out:
# [50 70 10 50 'C']
# [60 80 20 60 'B']
# [70 90 30 74 'A']

# %%
for i in df.index:
    print(i)
# Out:
# A
# B
# C

# %%
for i in df.columns:
    print(i)
# Out:
# Marks
# Percent
# new
# Marks_Extra
# Grade

# %%
for i in df:
    print(df[i])
# Out:
# Name
# A    50
# B    60
# C    70
# Name: Marks, dtype: int64
# Name
# A    70
# B    80
# C    90
# Name: Percent, dtype: int64
# Name
# A    10
# B    20
# C    30
# Name: new, dtype: int64
# Name
# A    50
# B    60
# C    74
# Name: Marks_Extra, dtype: int64
# Name
# A    C
# B    B
# C    A
# Name: Grade, dtype: object

# %%
def fun(x,val):
    return x*val

df.apply(fun,args=(3,))
# Out:
#       Marks  Percent  new  Marks_Extra Grade
# Name
# A       150      210   30          150   CCC
# B       180      240   60          180   BBB
# C       210      270   90          222   AAA

# %% [markdown]
# # concat

# %%
df1 = pd.DataFrame({'A':[1,2],'B':[6,7]})
df2 = pd.DataFrame({'A':[3,4],'B':[9,5]})

# %%
df1
# Out:
#    A  B
# 0  1  6
# 1  2  7

# %%
df2
# Out:
#    A  B
# 0  3  9
# 1  4  5

# %%
pd.concat([df1,df2])
# Out:
#    A  B
# 0  1  6
# 1  2  7
# 0  3  9
# 1  4  5

# %%
pd.concat??
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Source:
# def concat(
#     objs: Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame],
#     *,
#     axis: Axis = 0,
#     join: str = "outer",
#     ignore_index: bool = False,
#     keys: Iterable[Hashable] | None = None,
#     levels=None,
#     names: list[HashableT] | None = None,
#     verify_integrity: bool = False,
#     sort: bool = False,
#     copy: bool | None = None,
# ) -> DataFrame | Series:
#     """
#     Concatenate pandas objects along a particular axis.
#
# ...

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    A  B  A  B
# 0  1  6  3  9
# 1  2  7  4  5

# %%
df1 = pd.DataFrame({'A':[1,2],'B':[6,7]})
df2 = pd.DataFrame({'A':[3,4],'D':[9,5]})
pd.concat([df1,df2],join='outer')
# Out:
#    A    B    D
# 0  1  6.0  NaN
# 1  2  7.0  NaN
# 0  3  NaN  9.0
# 1  4  NaN  5.0

# %%
pd.concat([df1,df2],join='inner')
# Out:
#    A
# 0  1
# 1  2
# 0  3
# 1  4

# %%
pd.concat([df1,df2],join='inner',ignore_index=True)
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df2 = pd.DataFrame({'F':[3,4],'D':[9,5]})
df1 = pd.DataFrame({'A':[1,2],'E':[6,7]})
print(df1)
print(df2)
# Out:
#    A  E
# 0  1  6
# 1  2  7
#    F  D
# 0  3  9
# 1  4  5

# %%
pd.concat([df1,df2],sort=True)
# Out:
#      A    D    E    F
# 0  1.0  NaN  6.0  NaN
# 1  2.0  NaN  7.0  NaN
# 0  NaN  9.0  NaN  3.0
# 1  NaN  5.0  NaN  4.0

# %%
pd.concat([df1,df2],join="inner").shape
# Out:
# (4, 0)

# %%
empty=pd.DataFrame ([])
empty
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
empty.shape
# Out:
# (0, 0)

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({
    'Emp_id':[1,2,3,4],
    'Name':['A','B','C','D'],
    'dept_id':[10,20,10,40]
})
df2 =pd.DataFrame({
    'dept_id':[10,20,30],
    'dept':['IT','HR','Finance']
})
print(df1)
print(df2)
# Out:
#    Emp_id Name  dept_id
# 0       1    A       10
# 1       2    B       20
# 2       3    C       10
# 3       4    D       40
#    dept_id     dept
# 0       10       IT
# 1       20       HR
# 2       30  Finance

# %%
pd.merge(df1,df2,on='dept_id',how='inner')
# Out:
#    Emp_id Name  dept_id dept
# 0       1    A       10   IT
# 1       2    B       20   HR
# 2       3    C       10   IT

# %%
pd.merge(df1,df2,on='dept_id',how='left')
# Out:
#    Emp_id Name  dept_id dept
# 0       1    A       10   IT
# 1       2    B       20   HR
# 2       3    C       10   IT
# 3       4    D       40  NaN

# %%
pd.merge(df1,df2,on='dept_id',how='outer')
# Out:
#    Emp_id Name  dept_id     dept
# 0     1.0    A       10       IT
# 1     3.0    C       10       IT
# 2     2.0    B       20       HR
# 3     NaN  NaN       30  Finance
# 4     4.0    D       40      NaN

# %%
pd.merge(df1,df2,on='dept_id',how='right')
# Out:
#    Emp_id Name  dept_id     dept
# 0     1.0    A       10       IT
# 1     3.0    C       10       IT
# 2     2.0    B       20       HR
# 3     NaN  NaN       30  Finance

# %%
df1 = pd.DataFrame({
    'Emp_id':[1,2,3,4],
    'Name':['A','B','C','D'],
    'dept_id':[10,20,10,40]
})
df2 =pd.DataFrame({
    'd_id':[10,20,30],
    'dept':['IT','HR','Finance']
})
print(df1)
print(df2)
# Out:
#    Emp_id Name  dept_id
# 0       1    A       10
# 1       2    B       20
# 2       3    C       10
# 3       4    D       40
#    d_id     dept
# 0    10       IT
# 1    20       HR
# 2    30  Finance

# %%
pd.merge(df1,df2,left_on='dept_id',right_on='d_id')
# Out:
#    Emp_id Name  dept_id  d_id dept
# 0       1    A       10    10   IT
# 1       2    B       20    20   HR
# 2       3    C       10    10   IT

# %%
pd.merge(df1,df2,left_index=True,right_index=True)
# Out:
#    Emp_id Name  dept_id  d_id     dept
# 0       1    A       10    10       IT
# 1       2    B       20    20       HR
# 2       3    C       10    30  Finance

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how='outer')
# Out:
#    Emp_id Name  dept_id  d_id     dept
# 0       1    A       10  10.0       IT
# 1       2    B       20  20.0       HR
# 2       3    C       10  30.0  Finance
# 3       4    D       40   NaN      NaN

# %%
df1 = pd.DataFrame({
    'Emp_id':[1,2,3,4],
    'Name':['A','B','C','D'],
    'dept_id':[10,20,10,40]
})
df2 =pd.DataFrame({
    'd_id':[10,20,30],
    'Name':['IT','HR','Finance']
})
print(df1)
print(df2)
# Out:
#    Emp_id Name  dept_id
# 0       1    A       10
# 1       2    B       20
# 2       3    C       10
# 3       4    D       40
#    d_id     Name
# 0    10       IT
# 1    20       HR
# 2    30  Finance

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how='outer')
# Out:
#    Emp_id Name_x  dept_id  d_id   Name_y
# 0       1      A       10  10.0       IT
# 1       2      B       20  20.0       HR
# 2       3      C       10  30.0  Finance
# 3       4      D       40   NaN      NaN

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how='outer',suffixes=['_emp','_dept'])
# Out:
#    Emp_id Name_emp  dept_id  d_id Name_dept
# 0       1        A       10  10.0        IT
# 1       2        B       20  20.0        HR
# 2       3        C       10  30.0   Finance
# 3       4        D       40   NaN       NaN

# %%
pd.merge(df1,df2,left_on='dept_id',right_on='d_id',sort=True)
# Out:
#    Emp_id Name_x  dept_id  d_id Name_y
# 0       1      A       10    10     IT
# 1       3      C       10    10     IT
# 2       2      B       20    20     HR

# %%
df = pd.read_csv("loan.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 loan_status  Principal  terms effective_date  \
# 0             0           0     PAIDOFF       1000     30     09-08-2016
# 1             2           2     PAIDOFF       1000     30     09-08-2016
# 2             3           3     PAIDOFF       1000     15     09-08-2016
# 3             4           4     PAIDOFF       1000     30     09-09-2016
# 4             6           6     PAIDOFF       1000     30     09-09-2016
#
#      due_date  age             education  Gender
# 0  10-07-2016   45  High School or Below    male
# 1  10-07-2016   33              Bechalor  female
# 2   9/22/2016   27               college    male
# 3  10-08-2016   28               college  female
# 4  10-08-2016   29               college    male

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1,inplace=True)

# %%
df
# Out:
#    loan_status  Principal  terms effective_date    due_date  age  \
# 0      PAIDOFF       1000     30     09-08-2016  10-07-2016   45
# 1      PAIDOFF       1000     30     09-08-2016  10-07-2016   33
# 2      PAIDOFF       1000     15     09-08-2016   9/22/2016   27
# 3      PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 4      PAIDOFF       1000     30     09-09-2016  10-08-2016   29
# 5      PAIDOFF       1000     30     09-09-2016  10-08-2016   36
# 6      PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 7      PAIDOFF        800     15     09-10-2016   9/24/2016   26
# 8      PAIDOFF        300      7     09-10-2016   9/16/2016   29
# 9      PAIDOFF       1000     15     09-10-2016  10-09-2016   39
# 10     PAIDOFF       1000     30     09-10-2016  10-09-2016   26
# 11     PAIDOFF        900      7     09-10-2016   9/16/2016   26
# 12     PAIDOFF       1000      7     09-10-2016   9/16/2016   27
# ...

# %%
df['education'].unique()
# Out:
# array(['High School or Below', 'Bechalor', 'college'], dtype=object)

# %%
df.groupby('education')

# %%
df.groupby('education').mean(numeric_only=True)
# Out:
#                         Principal      terms        age
# education
# Bechalor              1000.000000  30.000000  33.000000
# High School or Below  1000.000000  21.166667  35.833333
# college                883.333333  22.416667  27.750000

# %%
df.groupby('education').sum(numeric_only=True)
# Out:
#                       Principal  terms  age
# education
# Bechalor                   1000     30   33
# High School or Below       6000    127  215
# college                   10600    269  333

# %%
df.groupby('education').agg(['min','max','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df.groupby('education').agg({'Principal':["mean",'max'],
                            'terms':'max'})
# Out:
#                         Principal       terms
#                              mean   max   max
# education
# Bechalor              1000.000000  1000    30
# High School or Below  1000.000000  1000    30
# college                883.333333  1000    30

# %%
df.groupby(['education','Gender','loan_status']).mean(numeric_only=True)
# Out:
#                                          Principal      terms        age
# education            Gender loan_status
# Bechalor             female PAIDOFF         1000.0  30.000000  33.000000
# High School or Below male   PAIDOFF         1000.0  21.166667  35.833333
# college              female PAIDOFF          950.0  18.500000  27.000000
#                      male   PAIDOFF          870.0  23.200000  27.900000

# %%
df.groupby(['education'])['terms'].mean()
# Out:
# education
# Bechalor                30.000000
# High School or Below    21.166667
# college                 22.416667
# Name: terms, dtype: float64

# %%
df.groupby(['education']).size()
# Out:
# education
# Bechalor                 1
# High School or Below     6
# college                 12
# dtype: int64

# %%
df.groupby(['education']).()
# Out:
#   Cell In[179], line 1
#     df.groupby(['education']).()
#                               ^
# SyntaxError: invalid syntax

# %%
df.groupby(['education']).count()
# Out:
#                       loan_status  Principal  terms  effective_date  due_date  \
# education
# Bechalor                        1          1      1               1         1
# High School or Below            6          6      6               6         6
# college                        12         12     12              12        12
#
#                       age  Gender
# education
# Bechalor                1       1
# High School or Below    6       6
# college                12      12

# %%
df.groupby(['education']).nunique()
# Out:
#                       loan_status  Principal  terms  effective_date  due_date  \
# education
# Bechalor                        1          1      1               1         1
# High School or Below            1          1      3               2         4
# college                         1          4      3               3         5
#
#                       age  Gender
# education
# Bechalor                1       1
# High School or Below    5       1
# college                 5       2

# %%
df.groupby(['education'])['terms'].apply(lambda x:x+4)
# Out:
# education
# Bechalor              1     34
# High School or Below  0     34
#                       9     19
#                       12    11
#                       14    34
#                       15    19
#                       16    34
# college               2     19
#                       3     34
#                       4     34
#                       5     34
#                       6     34
#                       7     19
#                       8     11
#                       10    34
#                       11    11
#                       13    19
#                       17    34
#                       18    34
# Name: terms, dtype: int64

# %%
def new(x):
    x['High_Term']=x['terms']>x['terms'].mean()
    return x
df.groupby(['education']).apply(new)
# Out:
# C:\Users\vdp87\AppData\Local\Temp\ipykernel_17496\862993857.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(['education']).apply(new)
#                         loan_status  Principal  terms effective_date  \
# education
# Bechalor             1      PAIDOFF       1000     30     09-08-2016
# High School or Below 0      PAIDOFF       1000     30     09-08-2016
#                      9      PAIDOFF       1000     15     09-10-2016
#                      12     PAIDOFF       1000      7     09-10-2016
#                      14     PAIDOFF       1000     30     09-10-2016
#                      15     PAIDOFF       1000     15     09-10-2016
# ...

# %%
df.groupby(['education']).nth(0)
# Out:
#   loan_status  Principal  terms effective_date    due_date  age  \
# 0     PAIDOFF       1000     30     09-08-2016  10-07-2016   45
# 1     PAIDOFF       1000     30     09-08-2016  10-07-2016   33
# 2     PAIDOFF       1000     15     09-08-2016   9/22/2016   27
#
#               education  Gender
# 0  High School or Below    male
# 1              Bechalor  female
# 2               college    male

# %%
df.groupby(['education']).nth(1)
# Out:
#   loan_status  Principal  terms effective_date    due_date  age  \
# 3     PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 9     PAIDOFF       1000     15     09-10-2016  10-09-2016   39
#
#               education  Gender
# 3               college  female
# 9  High School or Below    male

# %%
df.groupby(['education']).nth([0,1])
# Out:
#   loan_status  Principal  terms effective_date    due_date  age  \
# 0     PAIDOFF       1000     30     09-08-2016  10-07-2016   45
# 1     PAIDOFF       1000     30     09-08-2016  10-07-2016   33
# 2     PAIDOFF       1000     15     09-08-2016   9/22/2016   27
# 3     PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 9     PAIDOFF       1000     15     09-10-2016  10-09-2016   39
#
#               education  Gender
# 0  High School or Below    male
# 1              Bechalor  female
# 2               college    male
# 3               college  female
# 9  High School or Below    male

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#     terms loan_status effective_date             education    due_date  age  \
# 0      30     PAIDOFF     09-08-2016  High School or Below  10-07-2016   45
# 1      30     PAIDOFF     09-08-2016              Bechalor  10-07-2016   33
# 2      15     PAIDOFF     09-08-2016               college   9/22/2016   27
# 3      30     PAIDOFF     09-09-2016               college  10-08-2016   28
# 4      30     PAIDOFF     09-09-2016               college  10-08-2016   29
# 5      30     PAIDOFF     09-09-2016               college  10-08-2016   36
# 6      30     PAIDOFF     09-09-2016               college  10-08-2016   28
# 7      15     PAIDOFF     09-10-2016               college   9/24/2016   26
# 8       7     PAIDOFF     09-10-2016               college   9/16/2016   29
# 9      15     PAIDOFF     09-10-2016  High School or Below  10-09-2016   39
# 10     30     PAIDOFF     09-10-2016               college  10-09-2016   26
# ...

# %%
df.sort_values(by=['age','terms'])
# Out:
#    loan_status  Principal  terms effective_date    due_date  age  \
# 11     PAIDOFF        900      7     09-10-2016   9/16/2016   26
# 7      PAIDOFF        800     15     09-10-2016   9/24/2016   26
# 13     PAIDOFF        800     15     09-10-2016   9/24/2016   26
# 10     PAIDOFF       1000     30     09-10-2016  10-09-2016   26
# 17     PAIDOFF        800     30     09-10-2016  10-09-2016   26
# 18     PAIDOFF       1000     30     09-10-2016  10-09-2016   26
# 12     PAIDOFF       1000      7     09-10-2016   9/16/2016   27
# 2      PAIDOFF       1000     15     09-08-2016   9/22/2016   27
# 3      PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 6      PAIDOFF       1000     30     09-09-2016  10-08-2016   28
# 8      PAIDOFF        300      7     09-10-2016   9/16/2016   29
# 4      PAIDOFF       1000     30     09-09-2016  10-08-2016   29
# 15     PAIDOFF       1000     15     09-10-2016   9/24/2016   32
# ...

# %% [markdown]
# # PB147

# %% [markdown]
# ```
# Using ‘supermarket_sales.csv’ file do the following operations and give required answer by using proper programming process.
# 1).  Load the dataset into a pandas DataFrame and read first 8 rows.
# 2). Check for missing values and fill it by mean values of that particular column if any.
# 3).  Find the number of orders which have ‘Quantity’ less than 3 and which have (either ‘Rating’ greater than 8.5 or ‘Total’
# greater than 600).
# 4). Find the sum of ‘Total’ purchasing price spent by Member and Normal 'Customer type'.
# 5). Find the percentage of total of ‘gross income’ based on the different ‘Payment’ methods used by customers. (Ewallet, Cash
# and Credit card)
# 6). Analyze the purchasing behavior of male and female customers using ‘Gender’ column. Find their average purchase prices
# using ‘Total’ column.
# 7). Create a scatter plot that shows the relationship between total amount spent and rating.
# 8). Create a box plot that shows the distribution of ‘Rating’ and ‘Quantity’. And comment about outliers in both columns.
# 9). Visualize with parallel co-ordinates for ‘Unit price’, ‘Total’, ’cogs’ columns’ data with respect to ‘Product line’.
# ```

# %%
df = pd.read_csv("supermarket_sales.csv")
df.head(8)
# Out:
#    Unnamed: 0   invoice id branch       city customer type  gender  \
# 0           0  750-67-8428      A     Yangon        Member  Female
# 1           1  226-31-3081      C  Naypyitaw        Normal  Female
# 2           2  631-41-3108      A     Yangon        Normal    Male
# 3           3  123-19-1176      A     Yangon        Member    Male
# 4           4  373-73-7910      A     Yangon        Normal    Male
# 5           5  699-14-3026      C  Naypyitaw        Normal    Male
# 6           6  355-53-5943      A     Yangon        Member  Female
# 7           7  315-22-5665      C  Naypyitaw        Normal  Female
#
#              product line  unit price  quantity   tax 5%     total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   invoice id               1000 non-null   object
#  2   branch                   1000 non-null   object
#  3   city                     1000 non-null   object
#  4   customer type            996 non-null    object
#  5   gender                   995 non-null    object
#  6   product line             1000 non-null   object
#  7   unit price               1000 non-null   float64
#  8   quantity                 1000 non-null   int64
#  9   tax 5%                   1000 non-null   float64
#  10  total                    1000 non-null   float64
#  11  date                     1000 non-null   object
#  12  time                     1000 non-null   object
#  13  payment                  1000 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# invoice id                 0
# branch                     0
# city                       0
# customer type              4
# gender                     5
# product line               0
# unit price                 0
# quantity                   0
# tax 5%                     0
# total                      0
# date                       0
# time                       0
# payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               4
# rating                     0
# day_of_week                0
# dtype: int64

# %%
df['cogs'].fillna(df['cogs'].mean(),inplace=True)
df['Rating'].fillna(df['Rating'].mean(),inplace=True)
# Out:
# C:\Users\vdp87\AppData\Local\Temp\ipykernel_17496\3975897405.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cogs'].fillna(df['cogs'].mean(),inplace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
# ...

# %%
#Find the number of orders which have ‘Quantity’ less than 3 and which have (either ‘Rating’ greater than 8.5 or ‘Total’ greater than 600).
df.loc[(df["Quantity"]<3.0)& ((df["Rating"]>8.5)|(df["Total"]>600))].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[196], line 2
# ...

# %%
#Find the sum of ‘Total’ purchasing price spent by Member and Normal 'Customer type'.
df.groupby(['Customer type'])['Total'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[197], line 2
#       1 #Find the sum of ‘Total’ purchasing price spent by Member and Normal 'Customer type'.
# ----> 2 df.groupby(['Customer type'])['Total'].sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
print(df.loc[df["Customer type"]=="Member"]['Total'].sum())

# %%
print(df.loc[df["Customer type"]=="Normal"]['Total'].sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[198], line 1
# ----> 1 print(df.loc[df["Customer type"]=="Normal"]['Total'].sum())
#
# ...

# %%
#Find the percentage of total of ‘gross income’ based on the different ‘Payment’ methods used by customers. (Ewallet, Cash and Credit card)
df.loc[(df["Payment"]=="Ewallet")|(df["Payment"]=="Cash")|(df["Payment"]=="Card")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Payment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[199], line 2
# ...

# %%
df.groupby('Payment')['gross income'].sum()/df['gross income'].sum()*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[200], line 1
# ----> 1 df.groupby('Payment')['gross income'].sum()/df['gross income'].sum()*100
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
df.groupby("Gender")["Total"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 df.groupby("Gender")["Total"].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df["Total"],df["Rating"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[202], line 2
#       1 import matplotlib.pyplot as plt
# ...

# %%
import  seaborn as sns
sns.boxplot(data=df[["Rating","Quantity"]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 2
#       1 import  seaborn as sns
# ----> 2 sns.boxplot(data=df[["Rating","Quantity"]])
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
pd.plotting.parallel_coordinates(df,class_column='Product line',cols=["Unit price","Total","cogs"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product line'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[204], line 1
# ...
