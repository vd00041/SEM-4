# %% [markdown]
# # 1.js
# - write an express scprit to set cookies of submited values of form. perform following task create a  html file witch contains a form with fileds 1 firstname ,lastname, password and submitbuttion ones form submited store all this values to the respective cookies on /next page 3
# - then redirect user to /login page and clear the cookie set for the last name. display remaining cookie values use post method

# %% [markdown]
# # 2.js
# - write a express js using session to display  how many time user visited webside
# - if user is visiting first time then display welcome user else display number of count user visited webside use session

# %% [markdown]
# # 3.js
# - create 3.html file witch contains user name password and login buttion
# - after clickin submit buttion it shoud jump on /savesession page.
# - store username and passowrd in session
# - after saving session, redirect to '/fetch' page and read value, also put logout link.
# - jump on '/deletesession' page after clicking logout link.
# - distroy the session and go back to 3.html
