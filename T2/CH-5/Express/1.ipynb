# %% [markdown]
# # CH 5 Link Html ,CSS,JS FIles

# %% [markdown]
# - it will connect js file to html file
# ```
# app.use(express.static("forntEnd"))
# ```

# %% [markdown]
# ```
# const staticpath = path.join(__dirname, "../");
# //app.use(express.static(staticpath, { index: '1.html' }));
# app.get("/", (req, res) => {
#     res.sendFile(staticpath + "/1.html")
# })
# ```

# %% [markdown]
# ### write express to contain html contain create 1.js ,1.html,and 1.css into folders and js,html,css respectly

# %% [markdown]
# ### 3
# - write express script to get form data using get method and display data in json formate in next page /process. create html and js file seprately.

# %% [markdown]
# ### 4
# - write express js script to print massage in next line spliting by '.'
#
# - and use get method submit the data
# - html file contains form of text area for the massage and submit buttion.
# - create 4.html and 4.js in same folder

# %% [markdown]
# ### 5
# - Create One  html file witch contains two number input filds, one dropdown and witch contains
# addintion subtrection multiplaycation and division and one submit buttion
# - input filded must contains the value >0 else it will give a massage "please enter valid number"
# - also user must select one formula else give a massage you have not selected any formula
# - if one formula is sseletcted and number are entered then repective calculation will be perfon on the page "/calc" use get method

# %% [markdown]
# ### 6 Create a login form with filds, username password and submit buttion on form submition
# - "/login" if username is admin and password is "1234" display login success fully else display invalid details and provide link to go back
# - using post method

# %% [markdown]
# ### 7 create an html form that takes a number.
# - on submition, if input is empty then display "please enter a number" or input is not a number then display invild input.
#
# - if it is a number then display even number or odd number is the number is even and odd respective ly also provide link to go back
# - use two file html and js file also use http post method

# %% [markdown]
# ## Sesetion and cookeies
